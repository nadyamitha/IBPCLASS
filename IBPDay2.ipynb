# %% [markdown]
# <a href="https://colab.research.google.com/github/nadyamitha/IBPCLASS/blob/main/IBPDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
import numpy as np
import math

# %%
df= pd.read_csv(r'/content/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.size
# Out:
# 51450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df["YearsWithCurrManager"].unique()
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14])

# %%
#x=["YearsWithCurrManager", "YearsSinceLastPromotion"]
#df[x]
# Out:
#       YearsWithCurrManager  YearsSinceLastPromotion
# 0                        5                        0
# 1                        7                        1
# 2                        0                        0
# 3                        0                        3
# 4                        2                        2
# ...                    ...                      ...
# 1465                     3                        0
# 1466                     7                        1
# 1467                     3                        0
# 1468                     8                        0
# 1469                     2                        1
#
# [1470 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['YearsWithCurrManager'].plot(kind='hist', bins=20, title='YearsWithCurrManager')
# ...

# %%
from matplotlib import pyplot as plt
df['YearsSinceLastPromotion'].plot(kind='hist', bins=20, title='YearsSinceLastPromotion')
plt.gca().spines[['top', 'right',]].set_visible(True)

# %%
from matplotlib import pyplot as plt

# Assuming df is your DataFrame containing the data
data = df['YearsSinceLastPromotion']

# Plot histogram
plt.hist(data, bins=20)
plt.title('Years Since Last Promotion')
plt.xlabel('Years')
plt.ylabel('Frequency')

# Add labels on each bar
for i, freq in enumerate(plt.hist(data, bins=20)[0]):
    plt.text(plt.hist(data, bins=20)[1][i], freq, str(freq), ha='center', va='bottom')

plt.show()

# %%
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='YearsWithCurrManager', y='YearsSinceLastPromotion', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(True)

# %%
from matplotlib import pyplot as plt
df['YearsWithCurrManager'].plot(kind='hist', bins=20, title='YearsWithCurrManager')
plt.gca().spines[['top', 'right',]].set_visible(True)
plt.xlabel('Years With Current Manager')
plt.ylabel('Frequency')
plt.show()

# %%
from matplotlib import pyplot as plt

# Assuming df is your DataFrame containing the data
data = df['YearsWithCurrManager']

# Plot histogram
hist_data = plt.hist(data, bins=15)
plt.title('Years With Current Manager')
plt.xlabel('Years')
plt.ylabel('Frequency')

# Add labels on each bar
for i in range(len(hist_data[0])):
    plt.text(hist_data[1][i], hist_data[0][i], str(int(hist_data[0][i])), ha='center', va='bottom')

plt.show()

# %%
import seaborn as sns

# %%
df.plot.scatter('Age', 'MonthlyIncome')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# Highest income is seen between age 40 to 60

# %%
sns.boxplot(data=df[["Age", "YearsWithCurrManager"]]);

# %%
colors = ["red", "green", "blue", "yellow", "purple"]
color_dict = {
    "Male": "blue",
    "Female": "pink"}
sns.barplot(x='Gender', y='Age', capsize=0.1, data=df)
plt.title('Distribution of Gender by Age')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the data
colors = ["red", "green", "blue", "yellow", "purple"]
color_dict = {"Male": "blue", "Female": "pink"}

# Use palette to specify custom colors
sns.barplot(x='Gender', y='Age', capsize=0.1, palette=color_dict, data=df)

plt.title('Distribution of Gender by Age')
plt.xlabel('Gender')
plt.ylabel('Age')

plt.show()
# Out:
# <ipython-input-96-8e2a6a8b1b7d>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Age', capsize=0.1, palette=color_dict, data=df)

# %% [markdown]
# ### Regression Based Machine  Learning

# %%
from sklearn.linear_model import LinearRegression
import matplotlib
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ***with gender converting it into float***
#
# ---

# %%
gender_mapping = {'Male': 0, 'Female': 1}

# Map the 'Gender' column
df['Gender'] = df['Gender'].map(gender_mapping)

# Now df['Gender'] contains float values (0.0 for Male and 1.0 for Female)

# Select the desired columns
ab = ['YearsWithCurrManager', 'YearsSinceLastPromotion', 'Age', 'Gender', 'MonthlyIncome', 'YearsAtCompany']
df = df[ab]

# %% [markdown]
# ***without gender***

# %%
ab = ['YearsWithCurrManager', 'YearsSinceLastPromotion', 'Age', 'MonthlyIncome', 'YearsAtCompany']
df= df[ab]
df
# Out:
#       YearsWithCurrManager  YearsSinceLastPromotion  Age  MonthlyIncome  \
# 0                        5                        0   41           5993
# 1                        7                        1   49           5130
# 2                        0                        0   37           2090
# 3                        0                        3   33           2909
# 4                        2                        2   27           3468
# ...                    ...                      ...  ...            ...
# 1465                     3                        0   36           2571
# 1466                     7                        1   39           9991
# 1467                     3                        0   27           6142
# 1468                     8                        0   49           5390
# 1469                     2                        1   34           4404
#
#       YearsAtCompany
# 0                  6
# 1                 10
# 2                  0
# ...

# %% [markdown]
# Y is always be target variable

# %%
# All other variable
x=df.drop('YearsAtCompany', axis=1)
#Target
y= df['YearsAtCompany']
x
# Out:
#       YearsWithCurrManager  YearsSinceLastPromotion  Age  Gender  \
# 0                        5                        0   41       1
# 1                        7                        1   49       0
# 2                        0                        0   37       0
# 3                        0                        3   33       1
# 4                        2                        2   27       0
# ...                    ...                      ...  ...     ...
# 1465                     3                        0   36       0
# 1466                     7                        1   39       0
# 1467                     3                        0   27       0
# 1468                     8                        0   49       0
# 1469                     2                        1   34       0
#
#       MonthlyIncome
# 0              5993
# 1              5130
# 2              2090
# 3              2909
# 4              3468
# ...             ...
# 1465           2571
# ...

# %%
# using the train test split function
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=104,test_size=0.25,shuffle=True)

# %%
# create linear regression object
regr= LinearRegression()

# train the model using the training sets
regr.fit(x_train, y_trian)
# Out:
# LinearRegression()

# %%
# make predictions using the testing set
y_pred = regr.predict(x_test)

# %%
# the Co-efficients
print('Coefficient: \n', regr.coef_)
# Out:
# Coefficient:
#  [1.00076251e+00 4.31510854e-01 1.67810321e-02 2.80064820e-04]

# %%
# the mean squared error
print("Mean Squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared error: 9.99

# %%
r2_score(y_pred,y_test)
# Out:
# 0.5976239834421112

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import cross_val_score

# %%
# create Linear Regression object
random_r = RandomForestRegressor()

# train the model using the training sets
random_r.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_s = random_r.predict(x_test)

# %%
y_pred_s
# Out:
# array([ 3.95,  2.15,  1.91,  8.83,  8.45,  2.15, 28.93,  2.51,  2.15,
#         3.75,  4.65,  5.12,  7.47,  0.95,  5.19,  2.33, 11.43,  4.35,
#         8.24,  3.77,  4.32,  8.25,  5.01,  8.61,  6.59,  1.  , 11.25,
#         2.5 ,  6.51,  3.48, 15.15, 11.73,  4.17,  7.74,  0.74, 12.18,
#         0.88,  3.45,  2.32,  4.25,  8.74,  8.82,  4.7 , 15.37, 11.91,
#         7.67,  5.5 ,  4.01,  2.86, 11.39,  0.98,  7.45,  5.81,  2.16,
#         4.84,  3.38,  4.83,  3.35, 16.33,  4.25,  1.03,  6.  , 10.35,
#         3.07,  0.86, 10.93,  3.12,  8.14,  1.68,  8.19,  7.07,  0.86,
#        13.33, 11.85,  6.77,  1.  ,  7.57, 13.  ,  4.27,  0.83,  4.25,
#         4.57,  3.89,  4.82,  0.78,  3.33,  0.03,  3.56,  4.09,  2.56,
#        10.47,  5.08,  5.11, 20.26,  5.23,  7.57,  7.16,  9.73,  2.86,
#        12.15,  0.95,  3.65,  4.35,  9.1 , 15.18,  6.32,  8.89,  8.44,
#         4.53,  2.09,  1.02,  8.92,  1.15,  4.27, 12.31,  4.63, 17.69,
# ...

# %%
# Perform 5 fold cross-validation
scores= cross_val_score(random_r,x,y,cv=5)

# print the average score
print("Average cross-validation:", scores.mean())
# Out:
# Average cross-validation: 0.765541618685845

# %%
#Project- class work

# %% [markdown]
# #Assestment for Data Science Nadya Mitha

# %%
# x= ['YearswithCurrManager', 'YearsSinceLastPromotion', 'Age', 'MonthlyIncome', 'YearsAtCompany']

# add 2 more int variable
# Use decision tree regression
# Make 2 Plots of Visualization

# %%
# import libraries
import pandas as pd
import numpy as np
import math

# %%
df= pd.read_csv(r'/content/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
gender_mapping = {'Male': 0, 'Female': 1}

# Map the 'Gender' column
df['Gender'] = df['Gender'].map(gender_mapping)

# Now df['Gender'] contains float values (0.0 for Male and 1.0 for Female)

# Select the desired columns
ab = ['YearsWithCurrManager', 'YearsSinceLastPromotion', 'Age', 'Gender', 'MonthlyIncome', 'YearsAtCompany','YearsInCurrentRole']
df = df[ab]
df
# Out:
#       YearsWithCurrManager  YearsSinceLastPromotion  Age  Gender  \
# 0                        5                        0   41       1
# 1                        7                        1   49       0
# 2                        0                        0   37       0
# 3                        0                        3   33       1
# 4                        2                        2   27       0
# ...                    ...                      ...  ...     ...
# 1465                     3                        0   36       0
# 1466                     7                        1   39       0
# 1467                     3                        0   27       0
# 1468                     8                        0   49       0
# 1469                     2                        1   34       0
#
#       MonthlyIncome  YearsAtCompany  YearsInCurrentRole
# 0              5993               6                   4
# 1              5130              10                   7
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Drop rows with missing values
df.dropna(inplace=True)

# Splitting the data into features and target variable
x = df.drop(columns=['YearsAtCompany'])  # Features
y = df['YearsAtCompany']  # Target variable

# Splitting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=104, shuffle=True)

# Initializing the decision tree regression model
model = DecisionTreeRegressor()

# Training the model
model.fit(x_train, y_train)

# Predicting on the test set
y_pred = model.predict(x_test)

# Calculating Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 9.003401360544217
# <ipython-input-210-b7ab1892cdbb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
